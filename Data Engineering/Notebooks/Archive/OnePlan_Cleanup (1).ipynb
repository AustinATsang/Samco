# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

projectdf = spark.sql("SELECT * FROM OnePlan.Plan_Project")
taskdf = spark.sql("SELECT * FROM OnePlan.Tasks")
capdf = spark.sql("SELECT * FROM OnePlan.Capacity")
# Out:
# StatementMeta(, ef727b06-d1d4-4988-865d-86357862c8fb, 3, Finished, Available, Finished)

# %%
#display(capdf)
#display(projectdf)
# Out:
# StatementMeta(, ef727b06-d1d4-4988-865d-86357862c8fb, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 01044be4-7863-4f7b-ad52-a09d7736df52)

# %%
taskdf = taskdf.select(
        col('MSPWBS'),\
        col('WBS').alias('wbs'),\
        col('Name'),\
        col('Modified'),\
        col('Status'),\
        col('State'),\
        col('Priority'),\
        col('TaskStatus'),\
        col('RemainingEffort'),\
        col('StartDate'),\
        col('EndDate'),\
        col('Effort'),\
        col('Duration'),\
        col('Id'),\
    )
taskdf = taskdf.filter(taskdf.Name.contains('M7'))
#display(taskdf)
# Out:
# StatementMeta(, ef727b06-d1d4-4988-865d-86357862c8fb, 5, Finished, Available, Finished)

# %%
delta_table_path_project = "Tables/Project_Clean"
projectdf.write.format("delta").mode("overwrite").option("overwriteSchema","true").save(delta_table_path_project)
# Out:
# StatementMeta(, ef727b06-d1d4-4988-865d-86357862c8fb, 6, Finished, Available, Finished)
